# %%
from pathlib import Path

import numpy as onp
import matplotlib.pyplot as plt
import pandas as pd

# %%
RESULTSDIR = Path("out/msm/")

# %%
resultsfile = RESULTSDIR / "results.csv"

# %%
results = pd.read_csv(resultsfile)
results
# Out:
#     n_particles quantity      time  exact  level_zero_cutoff  p
# 0          3000   forces  0.000883  False                3.0  4
# 1          6000   forces  0.001517  False                3.0  4
# 2          9000   forces  0.002262  False                3.0  4
# 3         12000   forces  0.003015  False                3.0  4
# 4         15000   forces  0.003862  False                3.0  4
# 5         20000   forces  0.004980  False                3.0  4
# 6         28000   forces  0.006996  False                3.0  4
# 7         36000   forces  0.008939  False                3.0  4
# 8         48000   forces  0.011843  False                3.0  4
# 9         64000   forces  0.015972  False                3.0  4
# 10        80000   forces  0.019862  False                3.0  4
# 11       108000   forces  0.026453  False                3.0  4
# 12       135000   forces  0.033421  False                3.0  4
# 13       189000   forces  0.047688  False                3.0  4
# 14       243000   forces  0.060003  False                3.0  4
# 15       324000   forces  0.081706  False                3.0  4
# 16       405000   forces  0.102950  False                3.0  4
# 17       512000   forces  0.131190  False                3.0  4
# 18       640000   forces  0.165597  False                3.0  4

# %%
particle_numbers = results["n_particles"].values
times = results["time"].values

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Number of particles")
ax.set_ylabel("Time / ms")
ax.scatter(particle_numbers, times * 1000)
ax.set_xlim(0, ax.get_xlim()[1])
ax.set_ylim(0, ax.get_ylim()[1])
plt.show()

# %%
from msmjax.utils.benchmarking import path_input_structures

# %%
loaded = onp.load(path_input_structures / "structures_3000.npz")

# %%
0.5 * loaded["cells"][0]
# Out:
# array([[7.211248, 0.      , 0.      ],
#        [0.      , 7.211248, 0.      ],
#        [0.      , 0.      , 7.211248]], dtype=float32)
