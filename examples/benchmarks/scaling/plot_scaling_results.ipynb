# %%
from pathlib import Path

import numpy as onp
import matplotlib.pyplot as plt
import pandas as pd

# %%
RESULTSDIR = Path("out/bak/")

# %%
resultsfile = RESULTSDIR / "results.csv"

# %%
results = pd.read_csv(resultsfile)
results
# Out:
#     n_particles  level_zero_cutoff  p quantity      time
# 0          3000                3.0  4   forces  0.000929
# 1          6000                3.0  4   forces  0.001664
# 2          9000                3.0  4   forces  0.002218
# 3         12000                3.0  4   forces  0.002992
# 4         15000                3.0  4   forces  0.003874
# 5         20000                3.0  4   forces  0.005006
# 6         28000                3.0  4   forces  0.006894
# 7         36000                3.0  4   forces  0.008884
# 8         48000                3.0  4   forces  0.011788
# 9         64000                3.0  4   forces  0.015886
# 10        80000                3.0  4   forces  0.019528
# 11       108000                3.0  4   forces  0.025860
# 12       135000                3.0  4   forces  0.033030
# 13       189000                3.0  4   forces  0.046603
# 14       243000                3.0  4   forces  0.058746
# ...

# %%
particle_numbers = results["n_particles"].values
times = results["time"].values

# %%
fig, ax = plt.subplots()
ax.set_xlabel("Number of particles")
ax.set_ylabel("Time / ms")
ax.scatter(particle_numbers, times * 1000)
ax.set_xlim(0, ax.get_xlim()[1])
ax.set_ylim(0, ax.get_ylim()[1])
plt.show()

# %%
from msmjax.utils.benchmarking import path_input_structures

# %%
loaded = onp.load(path_input_structures / "structures_3000.npz")

# %%
0.5 * loaded["cells"][0]
# Out:
# array([[7.211248, 0.      , 0.      ],
#        [0.      , 7.211248, 0.      ],
#        [0.      , 0.      , 7.211248]], dtype=float32)
